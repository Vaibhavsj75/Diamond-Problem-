# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaibhavsj75/Diamond-Problem-/blob/main/Practical_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
NAME: Vaibhav Jadhav
ROLL_NO: 13211
BATCH: B1
# Out:
#   File "/tmp/ipykernel_287/1710506485.py", line 1
#     NAME: Vaibhav Jadhav
#                   ^
# SyntaxError: invalid syntax

# %%
print("Welcome")
# Out:
# Welcome

# %%
x=[10,20,30,40,50]

# %%
x.insert(3,35)

# %%
print(x)
# Out:
# [10, 20, 30, 35, 40, 50]

# %%
p={}

# %%
print("For display empty set")
# Out:
# For display empty set

# %%
p=set()

# %%
print("Empty set",p)
# Out:
# Empty set set()

# %%
print("Dictionary data is:")
# Out:
# Dictionary data is:

# %%
product={ "pid":101,"pname":'book', "pprice":'300rs'}

# %%
print("Data in Dictionary is:",product)
# Out:
# Data in Dictionary is: {'pid': 101, 'pname': 'book', 'pprice': '300rs'}

# %%
a=(4,5,7,20)

# %%
x=list(a)

# %%
print("Data in list is:",x)
# Out:
# Data in list is: [4, 5, 7, 20]

# %%
x.append(30)

# %%
print("Data in list is:",x)
# Out:
# Data in list is: [4, 5, 7, 20, 30]

# %%
student={"Rollno":101,"Name":'Vaibhav'}

# %%
print("Name of student:",student["Name"])
# Out:
# Name of student: Vaibhav

# %%
print("Name of student:",student["Rollno"])
# Out:
# Name of student: 101
